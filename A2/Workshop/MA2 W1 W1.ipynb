# %% [markdown]
# # Week 1: Workshop Activities (Putting Data Together)
# ---
#
# ## Practice Lists - Part 1
# ---
#
# 1. Select all valid lists below
#
# [] --> yes
#
# [-1, -5, 'a', 4, 'd'] --> yes
#
# [1, 2, 3, 4, 5] --> yes
#
# [[1, 2, 3], 'str', [4, 5]] --> no
#
# 2.  What is the output of the following program.
#
# ```python
# my_list = [1, 2, 3, 4, 5]
# my_list.append(3)
# print(my_list)
#
# my_list = my_list + [5] # think about why you need to assign it back to the list
# print(my_list)
#
# my_list = my_list + [1, 2, 3]
# print(my_list)
#
# my_list = [10, 20, 30] + my_list
# print(my_list)
#
# my_list.pop()
# print(my_list)
# ```

# %%
my_list = [1, 2, 3, 4, 5]
my_list.append(3)
print(my_list)

my_list = my_list + [5] # think about why you need to assign it back to the list
print(my_list) 

my_list = my_list + [1, 2, 3]
print(my_list) 

my_list = [10, 20, 30] + my_list
print(my_list) 

my_list.pop()
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 3]
# [1, 2, 3, 4, 5, 3, 5]
# [1, 2, 3, 4, 5, 3, 5, 1, 2, 3]
# [10, 20, 30, 1, 2, 3, 4, 5, 3, 5, 1, 2, 3]
# [10, 20, 30, 1, 2, 3, 4, 5, 3, 5, 1, 2]

# %% [markdown]
# 3. What is the output of the following program? Note the difference between `append` and `+` operator when you are dealing with two lists.
#
# ```python
# l1 = [1, 2, 3]
# l1 = l1 + [7, 8, 9]
# print(l1)
#
# l2 = [1, 2, 3]
# l2.append([7, 8, 9])
# print(l2)
# ```

# %%
l1 = [1, 2, 3]
l1 = l1 + [7, 8, 9]
print(l1)

l2 = [1, 2, 3]
l2.append([7, 8, 9])
print(l2)
# Out:
# [1, 2, 3, 7, 8, 9]
# [1, 2, 3, [7, 8, 9]]

# %% [markdown]
# 4. Check if 19 is in the following list: `[10, 20, 9, 22, 12, 19]`, Check if "dog" is in the following list: `["duck", 20, 9, 22, 12, 19]`

# %%
print(19 in [10, 20, 9, 22, 12, 19])
print('dog' in ["duck", 20, 9, 22, 12, 19])
# Out:
# True
# False

# %% [markdown]
# 5. Which characteristic do you observe in the list when analysing the output of the following code?
#
# ```python
# x = [1]
# print(id(x),':',x)
#
#
# x.append(5)
# x.extend([6,7])
# print(id(x),':',x)
# ```
# Did you notice how the value associated with the same identifier in memory has not changed? Why?

# %%
x = [1]
print(id(x),':',x)


x.append(5)
x.extend([6,7])
print(id(x),':',x)
# Out:
# 139914802979856 : [1]
# 139914802979856 : [1, 5, 6, 7]

# %% [markdown]
# 6. In this list [10, 20, 9, 22, 12, 19], access the following elements.
#
# * First element
# * Second element
# * Third element
# * Forth element

# %%
lst = [10, 20, 9, 22, 12, 19]
print(lst[0])
print(lst[1])
print(lst[2])
print(lst[3])
# Out:
# 10
# 20
# 9
# 22

# %% [markdown]
# 7. In the list following two lists, access the second element.
#
# ```python
# list1 = ['John', 'Danise', 'David', 'Danise']
# list2 = [12, 20, 30, 40]
# ```

# %%
list1 = ['John', 'Danise', 'David', 'Danise']
list2 = [12, 20, 30, 40]
print(list1[1])
print(list2[1])
# Out:
# Danise
# 20

# %% [markdown]
# 8. In the following list, access element 10.
# ```python
# [1, 'John', True, [10, 20, 9, 22, 12, 19]]
# ```

# %%
lst = [1, 'John', True, [10, 20, 9, 22, 12, 19]]
lst[3][0]
# Out:
# 10

# %% [markdown]
# ## Practice Lists - Part 2
# ---
# 1. What is the difference between append and extend? Write two example codes to illustrate the difference.

# %%
'''
append -- > append() adds a single element to the end of the list.
extend -- > xtend() can add multiple individual elements to the end of the list.
'''
lst1 = ['x',1 , 2 , 3]
lst2 = [4,5]
lst3 = lst1.append(lst2)
print(lst3)
lst4 = lst1.extend(lst2)
print(lst4)
# Out:
# None
# None
