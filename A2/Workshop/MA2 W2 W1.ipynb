# %% [markdown]
# # Week 1: Workshop Activities (Introduction to Functions)
# ---
#
# ## Reflective learning

# %% [markdown]
# 1. Write a program to display all the numbers which are divisible by 11 but not by 2 between 200 and 500.

# %%
for i in range(200,501,1):
    if i % 11 == 0 and i%2!=0:
        print(i)
# Out:
# 209
# 231
# 253
# 275
# 297
# 319
# 341
# 363
# 385
# 407
# 429
# 451
# 473
# 495

# %% [markdown]
# 2. Find errors in the following code.
# ```python
# x = int(“Enter any number”)
# for i in Range[2,6]
#     if x=i
#       print(“1”)
#     else
#       print(“2”)
# ```

# %%
x = int(input("Enter any number"))
for i in range(2,6):
    if x==i:
      print("1")
    else:
      print("2")
# Out:
# 2
# 2
# 1
# 2

# %% [markdown]
# 3. Write the output of the following.
# ```python
# for x in range(3):
#     for y in range(2):
#         print(“Practice Questions of loops in python”)
#     print()
# ```

# %%
for x in range(3):
    for y in range(2):
        print('Practice Questions of loops in python')
    print()
# Out:
# Practice Questions of loops in python
# Practice Questions of loops in python
#
# Practice Questions of loops in python
# Practice Questions of loops in python
#
# Practice Questions of loops in python
# Practice Questions of loops in python

# %% [markdown]
# 4. Write the output of the following.
# ```python
# for k in range(10,20,4):
#     print(k)
# ```

# %%
for k in range(10,20,4):
    print(k)
# Out:
# 10
# 14
# 18

# %% [markdown]
# 5. Write a Python program to check whether a given key already exists in a dictionary.

# %%
d1= {1:'hello', 2:'world', 3:'lol'}
if 4 in d1:
    print('yes')

# %% [markdown]
# 6. Write a Python program to remove duplicates from Dictionary.

# %%
d2 = {1:'hello', 2:'world', 3:'lol' }
# Out:
# 15

# %% [markdown]
# 7. Write a Python program to check whether a dictionary is empty or not.

# %%
d3 = {}
if len(d3)==0:
    print("empty dict")
# Out:
# empty dict

# %% [markdown]
# 8. Write a Python program to combine two dictionaries by adding values for common keys.

# %%
d1 = {'x': 100, 'y': 200, 'm':300}
d2 = {'x': 300, 'y': 200, 'z':400}
d3 = d1.copy()
for k,v in d2.items():
    try:
        d3[k]+=d2[k]
    except:
        d3[k]=d2[k]
print(d3)
# Out:
# {'x': 400, 'y': 400, 'm': 300, 'z': 400}

# %% [markdown]
# 9. Write a Python program to print all unique values in a dictionary.
# ```
# Sample Data : [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
# Expected Output : Unique Values: {'S005', 'S002', 'S007', 'S001', 'S009'}
# ```

# %%
SampleData = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
lst = []
unique = []
for i in SampleData:
    lst.extend(i.values())
##unique = set(lst)
for i in lst:
    if i not in unique:
        unique.append(i)
print(unique)
# Out:
# ['S001', 'S002', 'S005', 'S009', 'S007']

# %% [markdown]
# 10. Write a Python program to create and display all combinations of letters, selecting each letter from a different key in a dictionary.
# ```
# Sample data : {'1':['m','n'], '2':['x','y']}
# Expected Output:
# mx
# my
# nx
# ny
# ```

# %%
sample = {'1':['m','n'], '2':['x','y']}

for i in sample['1']:
    for j in sample['2']:
        print(i + j)
# Out:
# mx
# my
# nx
# ny
