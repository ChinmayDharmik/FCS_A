# %% [markdown]
# # ***D*** Week 1: Workshop Activities (Objects)
# ***

# %% [markdown]
# ## Practice Objects
# ---

# %% [markdown]
# 1. What are the key differences between procedural programming and OOP?
#
# | Procedural Oriented Programming                                                          | Object-Oriented Programming                                                             |
# |------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------|
# | In procedural programming, the program is divided into small parts called functions.     | In object-oriented programming, the program is divided into small parts called objects. |
# | Procedural programming follows a top-down approach.                                      | Object-oriented programming follows a bottom-up approach.                               |
# | There is no access specifier in procedural programming.                                  | Object-oriented programming has access specifiers like private, public, protected, etc. |
# | Adding new data and functions is not easy.                                               | Adding new data and function is easy.                                                   |
# | Procedural programming does not have any proper way of hiding data so it is less secure. | Object-oriented programming provides data hiding so it is more secure.                  |
# | In procedural programming, overloading is not possible.                                  | Overloading is possible in object-oriented programming.                                 |
# | In procedural programming, there is no concept of data hiding and inheritance.           | In object-oriented programming, the concept of data hiding and inheritance is used.     |
# | In procedural programming, the function is more important than the data.                 | In object-oriented programming, data is more important than function.                   |
# | Procedural programming is based on the unreal world.                                     | Object-oriented programming is based on the real world.                                 |
# | Procedural programming is used for designing medium-sized programs.                      | Object-oriented programming is used for designing large and complex programs.           |
# | Procedural programming uses the concept of procedure abstraction.                        | Object-oriented programming uses the concept of data abstraction.                       |
# | Code reusability absent in procedural programming,                                       | Code reusability present in object-oriented programming.                                |
# | Examples: C, FORTRAN, Pascal, Basic, etc.                                                | Examples: C++, Java, Python, C#, etc.                                                   |

# %% [markdown]
# 2. What is a class and how to define a class in Python? What is an object?

# %% [markdown]
# 3. What are attributes and methods?

# %% [markdown]
# 4. In your Jupyter Notebook, create the class definition for Flower. It should contain the following attributes
#
#     1. name
#     1. colour
#     1. sepal width
#     1. sepal height
#
# It should also have the following function bloom which prints the statement "The flower has bloomed".
#
# In your Jupyter Notebook, modify the bloom method to print the message "The 'name_of_flower' which is 'colour_of_the_flower' has bloomed". Create different instances of flowers and invoke the bloom method for each of them.

# %%
class Flower:
    ## attributes
    name = 'Rose'
    color = 'Yellow'
    sepal_width = 10
    sepal_height = 20
    def bloom(self):
        print(f"the {self.name} which is {self.color} has bloomed")

obj= Flower()
obj.bloom()
# Out:
# the Rose which is Yellow has bloomed

# %% [markdown]
# 5. Create a Python class Person with attributes: name and age of type string. Create a display() method that displays the name and age of an object created via the Person class.

# %%
class Person:
    ## attributes
    name = ''
    age = ''
    def init(self,n,a):
        self.name = n
        self.age = a
    def display(self):
        print(f'name: {self.name}\nage: {self.age}')

obj = Person()
obj.init('Chinmay','22')
obj.display()
# Out:
# name: Chinmay
# age: 22

# %% [markdown]
# 6. Write a Python program to create a Vehicle class with max_speed and mileage attributes. Create a show() method that displays the max_speed and mileage of an object created via the Vehicle class.

# %%
class Vehicle:
    max_speed = 100 
    mileage = 10
    def show(self):
        print(f'max_speed : {self.max_speed}\nmileage : {self.mileage}')
obj = Vehicle()
obj.show()
# Out:
# max_speed : 100
# mileage : 10
