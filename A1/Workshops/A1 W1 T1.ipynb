# %% [markdown]
# # Week 1: Workshop Activities (Environments & Jupyter Notebook)
# ***
# ---

# %% [markdown]
# ### Starting Python
# ---

# %% [markdown]
# * Print some messages. Use ? or help to see details on print().
# * Print your birth date.
# * Print 4+5, 10/2, (4+5)/3
# * Print the following statements: print("Hello!"), print("Hello!", "how are you?"), print("Hello!", "how are you?", "my age is: ", 12), print("Hello!", "how are you?", "I love programming"), print("Hello!", "how are you?", "I love programming", sep="\")
# * Print your first name, last name, age, and height

# %%
print("Yo!")
print("1st October 1999")
print(4+5,10/2,(4+5)/3)

# %% [markdown]
# ---
# ### Markdown
# ***

# %% [markdown]
# Use Markdown syntax to write the following.
#
# 1. Practice Markdown - Part 1

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# * One
#     * Sublist
#         * this
#     * Sublist
#         * this
#             * that
#         * and this
# * Two
#     * two point five
# * three
#     * jkjk
#
# Numeric list
# 1. Here we go
#     1. Sublist
#         1. This
#     1. Sublist
# 2. Now we continue
#
# Checked list( wont work in VSCODE)
#
# * [ ] Hi
#
# * [x] bye

# %% [markdown]
# 2. Practice Markdown - Part 2
#
# You can add horizontal rules:
# ```
# ---
# ```
# ---
# ```
# ***
# ```
# ***
#
#  ```python
# print("Hello World")
# ```
#
# $e^{i/\pi} +1 =0$
#
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}
#
# | This | is   |
# |------|------|
# |   ~~a~~ | table|
#
#
# <table>
# <tr>
# <th>Name</th>
# <th>Syntax</th>
# </tr>
# <tr>
# <td><strike>italic</strike></td>
# </tr>
# </table>
